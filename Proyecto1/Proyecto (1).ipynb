# %% [markdown]
# ![](https://www.dii.uchile.cl/wp-content/uploads/2021/06/Magi%CC%81ster-en-Ciencia-de-Datos.png)

# %% [markdown]
# # **Proyecto 1 - MDS7202 Laboratorio de Programación Científica para Ciencia de Datos 📚**
#
# **MDS7202: Laboratorio de Programación Científica para Ciencia de Datos**
#
# ### Cuerpo Docente:
#
# - Profesor: Ignacio Meza, Gabriel Iturra
# - Auxiliar: Sebastián Tinoco
# - Ayudante: Arturo Lazcano, Angelo Muñoz
#
# *Por favor, lean detalladamente las instrucciones de la tarea antes de empezar a escribir.*
#
# ### Equipo:
#
# - Isidora Luck
# - \<Segundo integrante\>
#
#
# ### Link de repositorio de GitHub: `https://github.com/IsidoraLuck/MDS7202.git`
#
# Fecha límite de entrega 📆: 27 de Octubre de 2023.

# %% [markdown]
# ----
#
# ## Reglas
#
# - **Grupos de 2 personas.**
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Estrictamente prohibida la copia.
# - Pueden usar cualquier material del curso que estimen conveniente.

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://worldskateamerica.org/wp-content/uploads/2023/07/SANTIAGO-2023-1-768x153.jpg" alt="Descripción de la imagen">
# </div>
#
# En un Chile azotado por un profundo caos político-económico y el resurgimiento de programas de televisión de dudosa calidad, todas las miradas y esperanzas son depositadas en el éxito de un único evento: Santiago 2023. La nación necesitaba desesperadamente un respiro, y los Juegos de Santiago 2023 prometían ser una luz al final del túnel.
#
# El Presidente de la República -conocido en las calles como Bombín-, consciente de la importancia de este evento para la revitalización del país, decide convocar a usted y su equipo en calidad de expertos en análisis de datos y estadísticas. Con gran solemnidad, el presidente les encomienda una importante y peligrosa: liderar un proyecto que permitiera caracterizar de forma automática y eficiente los datos generados por estos magnos juegos. Para esto, el presidente le destaca que la solución debe considerar los siguientes puntos:
# - Caracterización automática de los datos
# - La solución debe ser compatible con cualquier dataset
# - Se les facilita el dataset *olimpiadas.parquet*, el cual recopila data de diferentes juegos olímpicos realizados en los últimos años

# %% [markdown]
# ## 1.1 Creación de `Profiler` Class (4.0 puntos)
#
# Cree la clase `Profiler`. Como mínimo, esta debe tener las siguientes funcionalidades:
#
# 1. El método constructor, el cual debe recibir los datos a procesar en formato `Pandas DataFrame`. Además, este método debe generar una carpeta en su directorio de trabajo con el nombre `EDA_fecha`, donde `fecha` corresponda a la fecha de ejecución en formato `DD-MM-YYYY`.
#
# 2. El método `summarize`, el cual debe caracterizar las variables del Dataset. Como mínimo, se espera que su método pueda:
#     - Implementar una funcionalidad para filtrar y aplicar este método a una o más variables de interés.
#     - Reportar el tipo de variable
#     - Reportar el número y/o porcentaje de valores únicos de la variable
#     - Reportar el número y/o porcentaje de valores nulos
#     - Si la variables es numérica:
#         - Reportar el número y/o porcentaje de valores cero, negativos y outliers
#         - Reportar estadística descriptiva como el valor mínimo, máximo, promedio y los percentiles 25, 50, 75 y 100
#    - Levantar una alerta en caso de encontrar alguna anomalía fuera de lo común (el criterio debe ser ajustable por el usuario)
#    - Guardar sus resultados en el directorio `EDA_fecha/summary.txt`. El archivo debe separar de forma clara y ordenada los resultados de cada punto.
#
# 3. El método `plot_vars`, el cual debe graficar la distribución e interraciones de las variables del Dataset. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/plots`
#     - Implementar una funcionalidad para filtrar y aplicar este método a una o más variables de interés.
#     - Para las variables numéricas:
#         - Genere un gráfico de distribución de densidad
#         - Grafique la correlación entre las variables
#     - Para las variables categóricas:
#         - Genere un histograma de las top N categorías (N debe ser un parámetro ajustable)
#         - Grafique el coeficiente V de Cramer entre las variables
#     - Guardar cada gráfico generado en la carpeta `EDA_fecha/plots` en formato `.pdf` y bajo el naming `variable.pdf`, donde `variable` es el nombre de la variable de interés
#
# 4. El método `clean_data`, el cual debe limpiar los datos para que luego puedan ser procesados. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/clean_data`
#     - Implementar una funcionalidad para filtrar y aplicar este método a una o más variables de interés.
#     - Drop de valores duplicados
#     - Implementar como mínimo 2 técnicas para tratar los valores nulos, como:
#         - Drop de valores nulos
#         - Imputar valores nulos con alguna técnica de imputación
#         - Funcionalidad para escoger entre una técnica y la otra.
#     - Una de las columnas del dataframe presenta datos *no atómicos*. Separe dicha columna en las columnas que la compongan.
#         - Hint: ¿Qué caracteres permiten separar una columna de otra?
#         - Para las pruebas con el dataset nuevo, puede esperar que exista al menos una columna con este tipo de problema. Asuma que los separadores serán los mismos, aunque el número de columnas a separar puede ser distinto.
#     - Deberían usar `FunctionTransformer`.
#     - Guardar los datos procesados en formato `.csv` en el path `EDA_fecha/clean_data/data.csv`
#
# 5. El método `scale`, el cual debe preparar adecuadamente los datos para luego ser consumidos por algún tipo de algoritmo. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/scale`
#     - Procesar de forma adecuada los datos numéricos y categóricos:
#         - Su método debe recibir las técnicas de escalamiento como argumento de entrada (utilizar solo técnicas compatibles con el framework de `sklearn`)
#         - Para los atributos numéricos, se transforme los datos con un escalador logarítmico y un `MinMaxScaler`
#         - Asuma que no existen datos ordinales en su dataset
#     - Guardar todo este procesamiento en un `ColumnTransformer`.
#     - Guardar los datos limpios y transformados en formato `.csv` en el path `EDA_fecha/process/scaled_features.csv`
#
# 6. El método `make_clusters`, el cual debe generar clusters de los datos usando algún algoritmo de clusterización. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/clusters`
#     - Generar un estudio del codo donde señale la cantidad de clusters optimos para el desarrollo.
#     - Su método debe recibir el algoritmo de clustering como argumento de entrada (utilizar solo algoritmos compatibles con el framework de `sklearn`).
#     - No olvide pre procesar adecuadamente los datos antes de implementar la técnica de clustering.
#     - En este punto es espera que generen un `Pipeline` de sklearn. Además, su método debería usar lo construido en los puntos 4 y 5.
#     - Su método debe ser capaz de funcionar a partir de datos crudos (se descontará puntaje de lo contrario).
#     - Una vez generado los clusters, proyecte los datos a 2 dimensiones usando su técnica de reducción de dimensionalidad favorita y grafique los resultados coloreando por cluster.
#     - Guardar los datos con su respectivo cluster en formato `.csv` en el path `EDA_fecha/clusters/data_clusters.csv`. Guarde también los gráficos generados en el mismo path.
#
# 7. El método `detect_anomalies`, el cual debe detectar anomalías en los datos. Como mínimo, se espera que su método pueda:
#
#     - Crear la carpeta `EDA_fecha/anomalies`
#     - Implementar alguna técnica de detección de anomalías.
#     - Al igual que el punto anterior, su método debe considerar los siguientes puntos:
#         - No olvide pre procesar de forma adecuada los datos antes de implementar la técnica de detección de anomalía.
#         - En este punto es espera que generen un `Pipeline` de sklearn. Además, su método debería usar lo construido en los puntos 4 y 5.
#         - Su método debe ser capaz de funcionar a partir de datos crudos (se descontará puntaje de lo contrario).
#         - Su método debe recibir el algoritmo como argumento de entrada
#         - Una vez generado las etiquetas, proyecte los datos a 2 dimensiones y grafique los resultados coloreando por las etiquetas predichas por el detector de anomalías
#     - Guardar los datos con su respectiva etiqueta en formato `.csv` en el path `EDA_fecha/anomalies/data_anomalies.csv`. Guarde también los gráficos generados en el mismo path.
#
# 8. El método `profile`, el cual debe ejecutar todos los métodos anteriores.
#
# 9. Crear el método `clearGarbage` para eliminar las carpetas/archivos creados/as por la clase `Profiler`.
#
# Algunas consideraciones generales:
# - Su clase será testeada con datos tabulares diferentes a los provistos. No desarrollen código *hardcodeado*: su clase debe ser capaz de funcionar para **cualquier** dataset.
# - Aplique todo su conocimiento sobre buenas prácticas de programación: se evaluará que su código sea limpio y ordenado.
# - Recuerden documentar cada una de las funcionalidades que implementen.
# - Recuerden adjuntar sus `requirements.txt` junto a su entrega de proyecto. **El código que no se pueda ejecutar por imcompatibilidades de librerías no será corregido.**

# %%
import os
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.ensemble import IsolationForest
from scipy.stats import chi2_contingency
from sklearn.metrics import silhouette_score

# %%
class Profiler:

    def __init__(self, data, save_path='EDA'):
        """
        Constructor de la clase Profiler.

        Parameters:
        data (Pandas DataFrame): Los datos a procesar en formato DataFrame.
        save_path (str): Ruta donde se guardarán los resultados del análisis exploratorio de datos.

        Attributes:
        data (Pandas DataFrame): Almacena los datos proporcionados.
        timestamp (str): La fecha actual en formato "DD-MM-YYYY".
        eda_folder (str): La carpeta donde se guardarán los resultados del análisis exploratorio de datos.

        Returns:
        None
        """
        self.data = data
        self.save_path = save_path
        self.timestamp = datetime.datetime.now().strftime("%d-%m-%Y")
        self.eda_folder = os.path.join(self.save_path, f"EDA_{self.timestamp}")
        os.makedirs(self.eda_folder, exist_ok=True)
    def summarize(self, variables_of_interest=None, anomalies_threshold=0.05):
        """
        Caracteriza las variables del Dataset.

        Parameters:
        variables_of_interest (list): Lista de variables a analizar. Si es None, se analizan todas las variables.
        anomalies_threshold (float): Umbral para detectar anomalías. Si se supera, se genera una alerta.

        Returns:
        None
        """
        if not os.path.exists(self.eda_folder):
            os.makedirs(self.eda_folder)

        if variables_of_interest is None:
            variables_of_interest = self.data.columns

        summary_file = open(os.path.join(self.eda_folder, "summary.txt"), "w")

        for variable in variables_of_interest:
            summary_file.write(f"Variable: {variable}\n")
            summary_file.write(f"Tipo: {self.data[variable].dtype}\n")
            summary_file.write(f"Valores únicos: {self.data[variable].nunique()} ({100 * self.data[variable].nunique() / len(self.data):.2f}%)\n")
            summary_file.write(f"Valores nulos: {self.data[variable].isnull().sum()} ({100 * self.data[variable].isnull().sum() / len(self.data):.2f}%)\n")

            if self.data[variable].dtype in ['int64', 'float64']:
                summary_file.write(f"Valores cero: {len(self.data[self.data[variable] == 0])} ({100 * len(self.data[self.data[variable] == 0]) / len(self.data):.2f}%)\n")
                summary_file.write(f"Valores negativos: {len(self.data[self.data[variable] < 0])} ({100 * len(self.data[self.data[variable] < 0]) / len(self.data):.2f}%)\n")
                summary_file.write(f"Estadísticas descriptivas:\n{self.data[variable].describe()}\n")

                if self.data[variable].nunique() > 2:
                    z_score = (self.data[variable] - self.data[variable].mean()) / self.data[variable].std()
                    outliers = len(z_score[np.abs(z_score) > 3])
                    summary_file.write(f"Valores atípicos (z-score > 3): {outliers} ({100 * outliers / len(self.data):.2f}%)\n")
                    if outliers / len(self.data) > anomalies_threshold:
                        summary_file.write(f"¡Alerta! Más del {100 * anomalies_threshold:.2f}% de valores atípicos\n")
            summary_file.write("\n")

        summary_file.close()


    def plot_vars(self, variables_of_interest=None, n_top_categories=10):
        """
        Grafica la distribución e interacciones de las variables del Dataset.

        Parameters:
        variables_of_interest (list): Lista de variables a analizar. Si es None, se analizan todas las variables.
        n_top_categories (int): Número de categorías a mostrar en los histogramas de variables categóricas.

        Returns:
        None
        """
        if not os.path.exists(self.eda_folder):
            os.makedirs(self.eda_folder)

        if variables_of_interest is None:
            variables_of_interest = self.data.columns

        plots_folder = os.path.join(self.eda_folder, "plots")
        os.makedirs(plots_folder, exist_ok=True)

        for variable in variables_of_interest:
            if self.data[variable].dtype in ['int64', 'float64']:
                plt.figure(figsize=(8, 6))
                sns.histplot(self.data[variable], kde=True)
                plt.title(f"Distribución de {variable}")
                plt.xlabel(variable)
                plt.ylabel("Frecuencia")
                plt.savefig(os.path.join(plots_folder, f"{variable}.pdf"))
                plt.close()
            elif self.data[variable].dtype == 'object':
                top_n = self.data[variable].value_counts().head(n_top_categories)
                plt.figure(figsize=(8, 6))
                top_n.plot(kind='bar')
                plt.title(f"Top {n_top_categories} categorías de {variable}")
                plt.xlabel(variable)
                plt.ylabel("Frecuencia")
                plt.savefig(os.path.join(plots_folder, f"{variable}.pdf"))
                plt.close()
                if 'target' in self.data.columns:
                  le = LabelEncoder()
                  data_encoded = self.data[[variable]].apply(le.fit_transform)
                  data_encoded['target'] = self.data['target']
                  confusion_matrix = pd.crosstab(data_encoded[variable], data_encoded['target'])
                  chi2, _, _, _ = chi2_contingency(confusion_matrix)
                  cramers_v = np.sqrt(chi2 / (len(self.data) * min(confusion_matrix.shape) - 1))
                  plt.figure(figsize=(8, 6))
                  sns.heatmap(confusion_matrix, annot=True, fmt="d")
                  plt.title(f"Coeficiente V de Cramer entre {variable} y target: {cramers_v:.2f}")
                  plt.xlabel("target")
                  plt.ylabel(variable)
                  plt.savefig(os.path.join(plots_folder, f"{variable}_cramer.pdf"))
                  plt.close()



    def clean_data(self, variables_of_interest=None, duplicate_subset=None, impute_strategy='mean', atomic_column_contains=None, default_delimiters=['*', '(', ')', '?', ':', '¿']):
        """
        Limpia los datos para su procesamiento posterior.

        Parameters:
        variables_of_interest (list): Lista de variables a limpiar. Si es None, se limpian todas las variables.
        duplicate_subset (list): Lista de columnas para identificar duplicados.
        impute_strategy (str): Método de imputación para valores nulos ('mean', 'median', 'most_frequent', None).
        atomic_column_contains (str): Subcadena que deben contener las columnas no atómicas.
        default_delimiters (list): Lista de delimitadores sugeridos.

        Returns:
        Pandas DataFrame: Datos procesados.
        """
        data = self.data.copy()

        # 1. Crear la carpeta EDA_fecha/clean_data
        clean_data_path = f"{self.save_path}/clean_data"
        os.makedirs(clean_data_path, exist_ok=True)

        if duplicate_subset is not None:
            data.drop_duplicates(subset=duplicate_subset, inplace=True)

        atomic_columns = [col for col in data.columns if atomic_column_contains is not None and atomic_column_contains in col]

        if atomic_columns:
            best_delimiter = None
            best_split = None
            for delimiter in default_delimiters:
                atomic_splits = [data[col].str.split(delimiter, expand=True) for col in atomic_columns]
                non_null_columns = pd.concat(atomic_splits, axis=1).count(axis=1)
                if best_delimiter is None or non_null_columns.sum() > best_split.sum():
                    best_delimiter = delimiter
                    best_split = pd.concat(atomic_splits, axis=1)

            if best_delimiter is not None:
                atomic_columns_split = pd.concat([data] + [best_split], axis=1)
                data = atomic_columns_split
                data.drop(atomic_columns, axis=1, inplace=True)

        for variable in data.columns:
            if impute_strategy and data[variable].isnull().any():
                if data[variable].dtype in ['int64', 'float64']:
                    imputer = SimpleImputer(strategy=impute_strategy)
                    data[variable] = imputer.fit_transform(data[[variable]]).ravel()
                elif data[variable].dtype == 'object':
                    data = data.dropna(subset=[variable])

        # 2. Guardar los datos procesados en formato .csv en el path EDA_fecha/clean_data/data.csv
        clean_data_file = f"{clean_data_path}/data.csv"
        data.to_csv(clean_data_file, index=False)

        return data

    def scale(self, numerical_scalers=['log', 'min_max'], categorical_scalers=None):
        """
        Prepara adecuadamente los datos para luego ser consumidos por algún tipo de algoritmo.

        Parameters:
        numerical_scalers (list): Técnicas de escalamiento para atributos numéricos ('log', 'min_max', ...).
        categorical_scalers (list): Técnicas de codificación para atributos categóricos ('label_encoder', 'one_hot', ...).

        Returns:
        None
        """
        if not os.path.exists(self.eda_folder):
            os.makedirs(self.eda_folder)

        scale_folder = os.path.join(self.eda_folder, "scale")
        os.makedirs(scale_folder, exist_ok=True)

        numerical_features = self.data.select_dtypes(include=['int64', 'float64']).columns
        categorical_features = self.data.select_dtypes(include=['object']).columns

        transformers = []
        if 'log' in numerical_scalers:
            transformers.append(('log', FunctionTransformer(np.log1p, validate=False), numerical_features))
        if 'min_max' in numerical_scalers:
            transformers.append(('min_max', MinMaxScaler(), numerical_features))

        if categorical_scalers is not None:
            for scaler in categorical_scalers:
                if scaler == 'label_encoder':
                    for feature in categorical_features:
                        le = LabelEncoder()
                        self.data[feature] = le.fit_transform(self.data[feature])

        ct = ColumnTransformer(transformers, remainder='passthrough')
        transformed_data = ct.fit_transform(self.data)
        scaled_features = pd.DataFrame(transformed_data, columns=numerical_features.tolist() + categorical_features.tolist())
        scaled_features.to_csv(os.path.join(scale_folder, "scaled_features.csv"), index=False)


    def make_clusters(self, clustering_algorithm='KMeans', n_clusters_range=range(2, 11)):
        """
        Genera clusters de los datos usando algún algoritmo de clusterización.

        Parameters:
        clustering_algorithm (str): Algoritmo de clustering ('KMeans', 'otro').
        n_clusters_range (range): Rango de número de clusters para el estudio del codo.

        Returns:
        None
        """
        if not os.path.exists(self.eda_folder):
            os.makedirs(self.eda_folder)

        clusters_folder = os.path.join(self.eda_folder, "clusters")
        os.makedirs(clusters_folder, exist_ok=True)

        numerical_features = self.data.select_dtypes(include=['int64', 'float64']).columns

        if clustering_algorithm == 'KMeans':
            silhouette_scores = []
            for n_clusters in n_clusters_range:
                kmeans = KMeans(n_clusters=n_clusters)
                kmeans.fit(self.data[numerical_features])
                labels = kmeans.labels_
                silhouette_scores.append(silhouette_score(self.data[numerical_features], labels))

            optimal_n_clusters = n_clusters_range[np.argmax(silhouette_scores)]
            kmeans = KMeans(n_clusters=optimal_n_clusters)
            kmeans.fit(self.data[numerical_features])
            self.data['cluster'] = kmeans.labels_
            reduced_data = PCA(n_components=2).fit_transform(self.data[numerical_features])
            plt.figure(figsize=(8, 6))
            plt.scatter(reduced_data[:, 0], reduced_data[:, 1], c=self.data['cluster'], cmap='viridis')
            plt.title(f'Clusters (KMeans) - Silhouette Score: {np.max(silhouette_scores):.2f}')
            plt.savefig(os.path.join(clusters_folder, "clusters.pdf"))
            plt.close()
            self.data.to_csv(os.path.join(clusters_folder, "data_clusters.csv"), index=False)

    def detect_anomalies(self, anomaly_detection_algorithm='IsolationForest', anomalies_threshold=0.05):
        """
        Detecta anomalías en los datos.

        Parameters:
        anomaly_detection_algorithm (str): Algoritmo de detección de anomalías ('IsolationForest', 'otro').
        anomalies_threshold (float): Umbral para detectar anomalías.

        Returns:
        None
        """
        if not os.path.exists(self.eda_folder):
            os.makedirs(self.eda_folder)

        anomalies_folder = os.path.join(self.eda_folder, "anomalies")
        os.makedirs(anomalies_folder, exist_ok=True)

        numerical_features = self.data.select_dtypes(include=['int64', 'float64']).columns

        if anomaly_detection_algorithm == 'IsolationForest':
            clf = IsolationForest(contamination=anomalies_threshold)
            clf.fit(self.data[numerical_features])
            self.data['anomaly'] = clf.predict(self.data[numerical_features])
            reduced_data = PCA(n_components=2).fit_transform(self.data[numerical_features])
            plt.figure(figsize=(8, 6))
            plt.scatter(reduced_data[:, 0], reduced_data[:, 1], c=self.data['anomaly'], cmap='viridis')
            plt.title(f'Anomalies (Isolation Forest) - Threshold: {anomalies_threshold}')
            plt.savefig(os.path.join(anomalies_folder, "anomalies.pdf"))
            plt.close()
            self.data.to_csv(os.path.join(anomalies_folder, "data_anomalies.csv"), index=False)

    def profile(self, variables_of_interest=None, anomalies_threshold=0.05):
        """
        Ejecuta todos los métodos anteriores.

        Parameters:
        variables_of_interest (list): Lista de variables a analizar. Si es None, se analizan todas las variables.
        anomalies_threshold (float): Umbral para detectar anomalías. Si se supera, se genera una alerta.

        Returns:
        None
        """
        self.summarize(variables_of_interest, anomalies_threshold)
        self.plot_vars(variables_of_interest)
        self.clean_data()
        self.scale()
        self.make_clusters()
        self.detect_anomalies()

    def clearGarbage(self):
        """
        Elimina las carpetas/archivos creados por la clase Profiler.

        Returns:
        None
        """
        if os.path.exists(self.eda_folder):
            import shutil
            shutil.rmtree(self.eda_folder)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Cargar el dataset
data = pd.read_parquet('/content/drive/MyDrive/olimpiadas.parquet')

data
# Out:
#             ID                      Name Sex            Team  NOC  \
# 0            1                 A Dijiang   M           China  CHN
# 1            2                  A Lamusi   M           China  CHN
# 2            3       Gunnar Nielsen Aaby   M         Denmark  DEN
# 3            4      Edgar Lindenau Aabye   M  Denmark/Sweden  DEN
# 4            5  Christine Jacoba Aaftink   F     Netherlands  NED
# ...        ...                       ...  ..             ...  ...
# 271111  135569                Andrzej ya   M        Poland-1  POL
# 271112  135570                  Piotr ya   M          Poland  POL
# 271113  135570                  Piotr ya   M          Poland  POL
# 271114  135571        Tomasz Ireneusz ya   M          Poland  POL
# 271115  135571        Tomasz Ireneusz ya   M          Poland  POL
#
#               Games  Year  Season            City          Sport  \
# 0       1992 Summer  1992  Summer       Barcelona     Basketball
# ...

# %%
# Crear una instancia de la clase Profiler
profiler = Profiler(data, save_path='drive/MyDrive/EDA')

# Realizar el perfilado de los datos
profiler.profile()

# Limpiar archivos generados por la clase Profiler
profiler.clearGarbage()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-187d0571f6bf> in <cell line: 5>()
#       3
#       4 # Realizar el perfilado de los datos
# ----> 5 profiler.profile()
#       6
#       7 # Limpiar archivos generados por la clase Profiler
#
# <ipython-input-23-772dbbb3b30b> in profile(self, variables_of_interest, anomalies_threshold)
#     295         self.plot_vars(variables_of_interest)
#     296         self.clean_data()
# --> 297         self.scale()
#     298         self.make_clusters()
#     299         self.detect_anomalies()
#
# <ipython-input-23-772dbbb3b30b> in scale(self, numerical_scalers, categorical_scalers)
#     207         ct = ColumnTransformer(transformers, remainder='passthrough')
#     208         transformed_data = ct.fit_transform(self.data)
# ...

# %% [markdown]
# ## 1.2 Caracterizar datos de Olimpiadas (2.0 puntos)
#
# A partir de la clase que hemos desarrollado previamente, procederemos a realizar un análisis exhaustivo de los datos proporcionados en el enunciado. Este análisis se presentará en forma de un informe contenido en el mismo Jupyter Notebook y abordará los siguientes puntos:
#
# 1. Introducción
#     - Se proporcionará una breve descripción del problema que estamos abordando y se explicará la metodología que se seguirá.
#
# Elaborar una breve introducción con todo lo necesario para entender qué realizarán durante su proyecto. La idea es que describan de manera formal el proyecto con sus propias palabras y logren describir algunos aspectos básicos tanto del dataset como del análisis a realizar sobre los datos.
#
# Por lo anterior, en esta sección ustedes deberán ser capaces de:
#
# - Describir la tarea asociada al dataset.
# - Describir brevemente los datos de entrada que les provee el problema.
# - Plantear hipótesis de cómo podrían abordar el problema.
#
# 2. Análisis del EDA (Análisis Exploratorio de Datos)
#     - Se discutirán las observaciones y conclusiones obtenidas acerca de los datos proporcionados. A lo largo de su respuesta, debe responder preguntas como:
#         - ¿Como se comportan las variables numéricas? ¿y las categóricas?
#         - ¿Existen valores nulos en el dataset? ¿En qué columnas? ¿Cuantos?
#         - ¿Cuáles son las categorías y frecuencias de las variables categóricas?
#         - ¿Existen datos duplicados en el conjunto?
#         - ¿Existen relaciones o patrones visuales entre las variables?
#         - ¿Existen anomalías notables o preocupantes en los datos?
# 3. Creación de Clusters y Anomalías
#     - Se justificará la elección de los algoritmos a utilizar y sus hiperparámetros. En el caso de clustering, justifique además el número de clusters.
#
# 4. Análisis de Resultados
#     - Se examinarán los resultados obtenidos a partir de los clústers y anomalías generadas. ¿Se logra una separación efectiva de los datos? Entregue una interpretación de lo que representa cada clúster y anomalía.
# 5. Conclusión
#     - Se resumirán las principales conclusiones del análisis y se destacarán las implicaciones prácticas de los resultados obtenidos.

# %% [markdown]
# # 1.- Introducción
#
# En este proyecto, abordamos al desafío de analizar y caracterizar de manera automática los datos generados por los Juegos de Santiago 2023, pues este análisis contribuira a la revitalización del país, proporcionando información valiosa sobre el desarrollo y el desempeño de los juegos.
#
# ### 1.1- Descripción de la tarea
# La tarea principal es realizar un análisis exploratorio de datos (EDA) para comprender la naturaleza de los datos proporcionados en el conjunto *olimpiadas.parquet*. Este conjunto recopila datos de diferentes juegos olímpicos realizados en los últimos años. Nuestra misión es proporcionar información clave, identificar patrones, relaciones y posibles anomalías en los datos. Posteriormente, se podrán realizar clusters con los datos obtenidos.
#
# ### 1.2- Datos de entrada
# Contamos con el conjunto de datos *olimpiadas.parquet*, que recopila información sobre diferentes aspectos de los juegos olímpicos. Las columnas del conjunto de datos incluyen información sobre el ID del atleta, nombre, sexo, equipo, año de los juegos, temporada, ciudad, deporte, evento, medalla, edad, altura y peso. Este análisis se centrará en explorar estas variables y extraer información significativa para comprender mejor los juegos.
#
# ### 1.3- Hipótesis
# Se espera que la clase Profiler identifique automáticamente la diversidad de deportes y la participación de atletas de diversas partes del mundo. Tambien se cree que podemos identificar patrones de evolución en el rendimiento a lo largo de los años.
#
# La clase Profiler debería facilitar la identificación automática de variables que podrían influir en el éxito de un país o atleta en los juegos. Se utilizará para detectar automáticamente posibles anomalías en los datos. Se espera que identifique resultados inusuales o patrones atípicos que podrían requerir atención y análisis adicionales.
#
# # 2. Análisis del EDA (Análisis Exploratorio de Datos)
#
# En esta sección, llevaremos a cabo un análisis exhaustivo de los datos, respondiendo a preguntas clave y proporcionando observaciones sobre el comportamiento de las variables numéricas y categóricas, la presencia de valores nulos, duplicados, y cualquier patrón visual notable.
#
# Primero tenemos que ID solo cuenta con valores unicos, Name cuenta con valores tipo object, teniendo 134.732 (el 49.70%) de valores únicos, lo que indica que hay deportistas que se repiten según deporte, y 0 datos nulos, solo encontramos 2 generos tenindo 0 valores nulos,  que hay 1184 valores únicos, teniendo que muchos de los teams cuentan con varios deportistas.
#
# NOC cuenta con 230 valores únicos y 0 nulos, tenemos que han participado en 51 juegos distintos, los datos comprenden valores de 35 años distintos siendo el menor el 1896 y el mayor el 2016, sin encontrar valores fuera de rango, en cuanto a temporadas solo hay 2 en que se realizan juegos, los que han sido llevaados en 42 ciudades distintas, se tiene que se ha practicado 66 deportes, en 765 eventos, posteriormente, tenemos que en cuanto a la variable Medal encontramos 3 valores unicos correspondientes al tipo de medalla recibida y se encuentran 231.333 (85.33%) valores nulos, correspondientes a las personas que no han recibido medalla.
#
# Finalmente, tenemos la variable age-height-weight la que almacena la edad, altura y peso del alteta.
#
# Al analizar los graficos se tiene que la mayoria de las temporadas son en verano, las medallas son practicamente equitativas, los ultimos años ha aumentado la participación, teniendo que el team con más competidores es Estados Unidos.
#
# Se contaba con una columna no atomica, no fui capaz de modificarla.
#
# # 3. Creación de Clusters y Anomalías
#
# En esta etapa, se aplica clustering y detección de anomalías para segmentar y identificar patrones en los datos. Cabe destacar que no se logro llegar a esta etapa.
